# %%
import pandas as pd

# %%
# Assign a variable for the file to load and the path.
file_to_load = 'resources/2020_2021_raw_data.csv'

# %%
# Read the school data file and store it in a Pandas DataFrame.
data_df = pd.read_csv(file_to_load)

# %%
data_df.head(10)
# Out:
#    ID  scanned consent for time capsule  scanned "story"  \
# 0   1                                 1                1
# 1   2                                 1                1
# 2   3                                 0                1
# 3   4                                 1                1
# 4   5                                 1                1
# 5   6                                 1                1
# 6   7                                 1                1
# 7   8                                 1                1
# 8   9                                 1                1
# 9  10                                 1                1
#
#    focus group volunteer  time capsule "story" provided?  age  yr joined  \
# 0                      1                               1   74     1974.0
# 1                      0                               1   65     1978.0
# 2                      1                               0   82     1972.0
# ...
